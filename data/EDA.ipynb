# %% [markdown]
# # EDA on the Flight Delay Data

# %%
import os
import pandas as pd
from IPython.display import display_html
from pandasgui import show
import plotly.express as px
from IPython.display import Image

# %%
from IPython.core.display import display, HTML

def display_side_by_side(dfs:list, captions:list):
    """Display tables side by side to save vertical space
    Input:
        dfs: list of pandas.DataFrame
        captions: list of table captions
    """
    output = ""
    combined = dict(zip(captions, dfs))
    for caption, df in combined.items():
        output += df.style.set_table_attributes("style='display:inline'").set_caption(caption)._repr_html_()
        output += "\xa0\xa0\xa0"
    display(HTML(output))

# %%
airlines = pd.read_csv("airlines.csv")
airport = pd.read_csv("airports.csv")
flights_train = pd.read_csv("flights_train.csv")
flights_test = pd.read_csv("flights_test.csv")
submit_sample = pd.read_csv("submit_sample.csv")

# %%
all_dfs = [airlines.head(5), airport.head(5), submit_sample.head(5), flights_train.head(5), flights_test.head(5)]
all_df_names = ["airlines","airport","submit_sample","flights_train","flights_test"]

display_side_by_side(all_dfs, all_df_names)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fc069_" style='display:inline'>
#   <caption>airlines</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >IATA_CODE</th>
#       <th class="col_heading level0 col1" >AIRLINE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc069_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc069_row0_col0" class="data row0 col0" >UA</td>
#       <td id="T_fc069_row0_col1" class="data row0 col1" >United Air Lines Inc.</td>
#     </tr>
#     <tr>
#       <th id="T_fc069_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc069_row1_col0" class="data row1 col0" >AA</td>
#       <td id="T_fc069_row1_col1" class="data row1 col1" >American Airlines Inc.</td>
#     </tr>
#     <tr>
#       <th id="T_fc069_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
flights_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2818553 entries, 0 to 2818552
# Data columns (total 18 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   id                   int64
#  1   YEAR                 int64
#  2   MONTH                int64
#  3   DAY                  int64
#  4   DAY_OF_WEEK          int64
#  5   AIRLINE              object
#  6   FLIGHT_NUMBER        int64
#  7   TAIL_NUMBER          object
#  8   ORIGIN_AIRPORT       object
#  9   DESTINATION_AIRPORT  object
#  10  SCHEDULED_DEPARTURE  int64
#  11  DEPARTURE_TIME       float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  DISTANCE             int64
#  16  SCHEDULED_ARRIVAL    int64
#  17  ARRIVAL_DELAY        float64
# dtypes: float64(5), int64(9), object(4)
# memory usage: 387.1+ MB

# %%
flights_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514384 entries, 0 to 514383
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   514384 non-null  int64
#  1   YEAR                 514384 non-null  int64
#  2   MONTH                514384 non-null  int64
#  3   DAY                  514384 non-null  int64
#  4   DAY_OF_WEEK          514384 non-null  int64
#  5   AIRLINE              514384 non-null  object
#  6   FLIGHT_NUMBER        514384 non-null  int64
#  7   TAIL_NUMBER          514384 non-null  object
#  8   ORIGIN_AIRPORT       514384 non-null  object
#  9   DESTINATION_AIRPORT  514384 non-null  object
#  10  SCHEDULED_DEPARTURE  514384 non-null  int64
#  11  DEPARTURE_TIME       514384 non-null  float64
#  12  TAXI_OUT             514384 non-null  float64
#  13  WHEELS_OFF           514384 non-null  float64
#  14  SCHEDULED_TIME       514384 non-null  float64
# ...

# %%
flights_train.isnull().values.any(), flights_test.isnull().values.any()
# Out:
# (False, False)

# %%
show(flights_train)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI

# %%
Image(filename='plots/train_full_dataframe_statistics.png')

# %%
Image(filename='plots/origin_airports_wc.png')

# %%
Image(filename='plots/destination_airports_wc.png')

# %%
Image(filename='plots/box_plot_delays_over_day.png')

# %%
Image(filename='plots/flight_delays_over_airlines.png')

# %%
Image(filename='plots/scheduled_arrival_vs_arrival_delay_scatter.png')

# %%
Image(filename='plots/count_scheduled_arrival_vs_day.png')

# %%
Image(filename='plots/count_scheduled_departure_vs_day.png')

# %%
Image(filename='plots/scheduled_arrival_vs_day_and_arrival_delay.png')

# %%
Image(filename='plots/scheduled_departure_vs_day_and_arrival_delay.png')
